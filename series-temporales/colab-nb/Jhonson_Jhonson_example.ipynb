# %% [markdown]
# # Ganancias trimestrales de Jhonson y Jhonson.

# %%
suppressPackageStartupMessages({
  library(astsa)
  library(tsibble)
  library(ggplot2)
  library(fable)
  library(feasts)
})

# %% [markdown]
# La figura muestra las ganancias trimestrales por acción de la empresa estadounidense _Johnson & Johnson_, proporcionada por el profesor Paul Griffin (comunicación personal) de la _Graduate School of Management_ de la Universidad de California, Davis. Hay 84 trimestres (21 años) medidos desde el primer trimestre de 1960 hasta el último trimestre de 1980.

# %%
jj |> 
  as_tsibble() |>
  autoplot(value) +
    ggtitle("Pasajeros de la Clase Económica: Melbourne-Sydney") +
    xlab("Año") +
    ylab("Miles") +
    theme_light()
# Out:
# plot without title

# %% [markdown]
# Los resultados obtenidos en el [Problema 2.1](https://github.com/Ryuta2329/Msc-Math-Applied/blob/main/Series%20Temporales/output/Shumway-Stoffer-Solutions.md#capitulo-2) muestran que, al eliminar el componente con tendencia y los componentes trimestrales, se obtiene una serie con componente autoregresivo de primer orden, requiriendo porbablemente una primera diferencia para llevarlos a estacionaridad.
